# %%
#  let's find the correct momentum for a circular orbit in XY
from math import pi, sqrt

pos_x = 3.0
pos_y = 2.5
charge = -4.8e-10
mass = 9.8e-28
momentum_y = 3.92e-19
field_x = lambda x, y: 8 * (x - 2.5) / ( (x - 2.5)**2 + (y - 2.5)**2 )**(3/2)
field_y = lambda x, y: 8 * (y - 2.5) / ( (x - 2.5)**2 + (y - 2.5)**2 )**(3/2)
pot_en = lambda x, y: 8 * charge * ((x - 2.5)**2 + (y - 2.5)**2) ** (-1/2)
orbit_radius = pos_x - 2.5
force = abs(charge*field_x(pos_x, pos_y))
v = sqrt(force/mass * orbit_radius)
good_momentum = v*mass
print(good_momentum)
# Out:
# 2.7434285119171595e-18

# %%
from ef.config.config import Config
from ef.config.visualizer import Visualizer3d
conf = Config.from_fname("single_particle_in_radial_electric_field.conf")
conf.output_file.format_ = 'history'
conf.visualize_all(Visualizer3d())
print(conf)
# Out:
# ### Config:
# time_grid = TimeGridConf(total=3e-09, save_step=3e-11, step=3e-12)
# spatial_mesh = SpatialMeshConf(size=array([5., 5., 8.]), step=array([0.5, 0.5, 0.5]))
# sources = [ParticleSourceConf(name='emit_single_particle', shape=Box(origin=array([3. , 2.5, 1. ]), size=array([0.01, 0.01, 0.01])), initial_particles=1, particles_to_generate_each_step=0, momentum=array([0.0000e+00, 2.7434e-18, 1.7700e-19]), temperature=0.0, charge=-4.8e-10, mass=9.8e-28)]
# inner_regions = []
# output_file = OutputFileConf(prefix='single_particle_in_radial_el_field_', suffix='.h5', format_='history')
# boundary_conditions = BoundaryConditionsConf(right=0.0, left=0.0, bottom=0.0, top=0.0, near=0.0, far=0.0)
# particle_interaction_model = ParticleInteractionModelConf(model='noninteracting')
# external_fields = [ExternalFieldExpressionConf(name='el_radial', electric_or_magnetic='electric', field=('8 * (x - 2.5) / ( (x - 2.5)**2 + (y - 2.5)**2 )**(3/2)', '8 * (y - 2.5) / ( (x - 2.5)**2 + (y - 2.5)**2 )**(3/2)', '0.0'))]

# %%
conf.make().start()
# Out:
# Writing initial fields to file
# Writing to file single_particle_in_radial_el_field_fieldsWithoutParticles_new.h5
# Writing to file single_particle_in_radial_el_field_fieldsWithoutParticles.h5
# Creating history file single_particle_in_radial_el_field_history.h5
# Writing step 0 to file
# Time step from 0 to 1 of 1000
# Time step from 1 to 2 of 1000
# Time step from 2 to 3 of 1000
# Time step from 3 to 4 of 1000
# Time step from 4 to 5 of 1000
# Time step from 5 to 6 of 1000
# Time step from 6 to 7 of 1000
# Time step from 7 to 8 of 1000
# Time step from 8 to 9 of 1000
# Time step from 9 to 10 of 1000
# Writing step 10 to file
# Time step from 10 to 11 of 1000
# Time step from 11 to 12 of 1000
# Time step from 12 to 13 of 1000
# Time step from 13 to 14 of 1000
# Time step from 14 to 15 of 1000
# Time step from 15 to 16 of 1000
# Time step from 16 to 17 of 1000
# Time step from 17 to 18 of 1000
# Time step from 18 to 19 of 1000
# Time step from 19 to 20 of 1000
# Writing step 20 to file
# Time step from 20 to 21 of 1000
# Time step from 21 to 22 of 1000
# Time step from 22 to 23 of 1000
# Time step from 23 to 24 of 1000
# Time step from 24 to 25 of 1000
# Time step from 25 to 26 of 1000
# Time step from 26 to 27 of 1000
# Time step from 27 to 28 of 1000
# Time step from 28 to 29 of 1000
# Time step from 29 to 30 of 1000
# Writing step 30 to file
# Time step from 30 to 31 of 1000
# Time step from 31 to 32 of 1000
# Time step from 32 to 33 of 1000
# Time step from 33 to 34 of 1000
# Time step from 34 to 35 of 1000
# Time step from 35 to 36 of 1000
# Time step from 36 to 37 of 1000
# Time step from 37 to 38 of 1000
# Time step from 38 to 39 of 1000
# Time step from 39 to 40 of 1000
# Writing step 40 to file
# Time step from 40 to 41 of 1000
# Time step from 41 to 42 of 1000
# Time step from 42 to 43 of 1000
# Time step from 43 to 44 of 1000
# Time step from 44 to 45 of 1000
# Time step from 45 to 46 of 1000
# Time step from 46 to 47 of 1000
# Time step from 47 to 48 of 1000
# Time step from 48 to 49 of 1000
# Time step from 49 to 50 of 1000
# Writing step 50 to file
# Time step from 50 to 51 of 1000
# Time step from 51 to 52 of 1000
# Time step from 52 to 53 of 1000
# Time step from 53 to 54 of 1000
# Time step from 54 to 55 of 1000
# Time step from 55 to 56 of 1000
# Time step from 56 to 57 of 1000
# Time step from 57 to 58 of 1000
# Time step from 58 to 59 of 1000
# Time step from 59 to 60 of 1000
# Writing step 60 to file
# Time step from 60 to 61 of 1000
# Time step from 61 to 62 of 1000
# Time step from 62 to 63 of 1000
# Time step from 63 to 64 of 1000
# Time step from 64 to 65 of 1000
# Time step from 65 to 66 of 1000
# Time step from 66 to 67 of 1000
# Time step from 67 to 68 of 1000
# Time step from 68 to 69 of 1000
# Time step from 69 to 70 of 1000
# Writing step 70 to file
# Time step from 70 to 71 of 1000
# Time step from 71 to 72 of 1000
# Time step from 72 to 73 of 1000
# Time step from 73 to 74 of 1000
# Time step from 74 to 75 of 1000
# Time step from 75 to 76 of 1000
# Time step from 76 to 77 of 1000
# Time step from 77 to 78 of 1000
# Time step from 78 to 79 of 1000
# Time step from 79 to 80 of 1000
# Writing step 80 to file
# Time step from 80 to 81 of 1000
# Time step from 81 to 82 of 1000
# Time step from 82 to 83 of 1000
# Time step from 83 to 84 of 1000
# Time step from 84 to 85 of 1000
# Time step from 85 to 86 of 1000
# Time step from 86 to 87 of 1000
# Time step from 87 to 88 of 1000
# Time step from 88 to 89 of 1000
# Time step from 89 to 90 of 1000
# Writing step 90 to file
# Time step from 90 to 91 of 1000
# Time step from 91 to 92 of 1000
# Time step from 92 to 93 of 1000
# Time step from 93 to 94 of 1000
# Time step from 94 to 95 of 1000
# Time step from 95 to 96 of 1000
# Time step from 96 to 97 of 1000
# Time step from 97 to 98 of 1000
# Time step from 98 to 99 of 1000
# Time step from 99 to 100 of 1000
# Writing step 100 to file
# Time step from 100 to 101 of 1000
# Time step from 101 to 102 of 1000
# Time step from 102 to 103 of 1000
# Time step from 103 to 104 of 1000
# Time step from 104 to 105 of 1000
# Time step from 105 to 106 of 1000
# Time step from 106 to 107 of 1000
# Time step from 107 to 108 of 1000
# Time step from 108 to 109 of 1000
# Time step from 109 to 110 of 1000
# Writing step 110 to file
# Time step from 110 to 111 of 1000
# Time step from 111 to 112 of 1000
# Time step from 112 to 113 of 1000
# Time step from 113 to 114 of 1000
# Time step from 114 to 115 of 1000
# Time step from 115 to 116 of 1000
# Time step from 116 to 117 of 1000
# Time step from 117 to 118 of 1000
# Time step from 118 to 119 of 1000
# Time step from 119 to 120 of 1000
# Writing step 120 to file
# Time step from 120 to 121 of 1000
# Time step from 121 to 122 of 1000
# Time step from 122 to 123 of 1000
# Time step from 123 to 124 of 1000
# Time step from 124 to 125 of 1000
# Time step from 125 to 126 of 1000
# Time step from 126 to 127 of 1000
# Time step from 127 to 128 of 1000
# Time step from 128 to 129 of 1000
# Time step from 129 to 130 of 1000
# Writing step 130 to file
# Time step from 130 to 131 of 1000
# Time step from 131 to 132 of 1000
# Time step from 132 to 133 of 1000
# Time step from 133 to 134 of 1000
# Time step from 134 to 135 of 1000
# Time step from 135 to 136 of 1000
# Time step from 136 to 137 of 1000
# Time step from 137 to 138 of 1000
# Time step from 138 to 139 of 1000
# Time step from 139 to 140 of 1000
# Writing step 140 to file
# Time step from 140 to 141 of 1000
# Time step from 141 to 142 of 1000
# Time step from 142 to 143 of 1000
# Time step from 143 to 144 of 1000
# Time step from 144 to 145 of 1000
# Time step from 145 to 146 of 1000
# Time step from 146 to 147 of 1000
# Time step from 147 to 148 of 1000
# Time step from 148 to 149 of 1000
# Time step from 149 to 150 of 1000
# Writing step 150 to file
# Time step from 150 to 151 of 1000
# Time step from 151 to 152 of 1000
# Time step from 152 to 153 of 1000
# Time step from 153 to 154 of 1000
# Time step from 154 to 155 of 1000
# Time step from 155 to 156 of 1000
# Time step from 156 to 157 of 1000
# Time step from 157 to 158 of 1000
# Time step from 158 to 159 of 1000
# Time step from 159 to 160 of 1000
# Writing step 160 to file
# Time step from 160 to 161 of 1000
# Time step from 161 to 162 of 1000
# Time step from 162 to 163 of 1000
# Time step from 163 to 164 of 1000
# Time step from 164 to 165 of 1000
# Time step from 165 to 166 of 1000
# Time step from 166 to 167 of 1000
# Time step from 167 to 168 of 1000
# Time step from 168 to 169 of 1000
# Time step from 169 to 170 of 1000
# Writing step 170 to file
# Time step from 170 to 171 of 1000
# Time step from 171 to 172 of 1000
# Time step from 172 to 173 of 1000
# Time step from 173 to 174 of 1000
# Time step from 174 to 175 of 1000
# Time step from 175 to 176 of 1000
# Time step from 176 to 177 of 1000
# Time step from 177 to 178 of 1000
# Time step from 178 to 179 of 1000
# Time step from 179 to 180 of 1000
# Writing step 180 to file
# Time step from 180 to 181 of 1000
# Time step from 181 to 182 of 1000
# Time step from 182 to 183 of 1000
# Time step from 183 to 184 of 1000
# Time step from 184 to 185 of 1000
# Time step from 185 to 186 of 1000
# Time step from 186 to 187 of 1000
# Time step from 187 to 188 of 1000
# Time step from 188 to 189 of 1000
# Time step from 189 to 190 of 1000
# Writing step 190 to file
# Time step from 190 to 191 of 1000
# Time step from 191 to 192 of 1000
# Time step from 192 to 193 of 1000
# Time step from 193 to 194 of 1000
# Time step from 194 to 195 of 1000
# Time step from 195 to 196 of 1000
# Time step from 196 to 197 of 1000
# Time step from 197 to 198 of 1000
# Time step from 198 to 199 of 1000
# Time step from 199 to 200 of 1000
# Writing step 200 to file
# Time step from 200 to 201 of 1000
# Time step from 201 to 202 of 1000
# Time step from 202 to 203 of 1000
# Time step from 203 to 204 of 1000
# Time step from 204 to 205 of 1000
# Time step from 205 to 206 of 1000
# Time step from 206 to 207 of 1000
# Time step from 207 to 208 of 1000
# Time step from 208 to 209 of 1000
# Time step from 209 to 210 of 1000
# Writing step 210 to file
# Time step from 210 to 211 of 1000
# Time step from 211 to 212 of 1000
# Time step from 212 to 213 of 1000
# Time step from 213 to 214 of 1000
# Time step from 214 to 215 of 1000
# Time step from 215 to 216 of 1000
# Time step from 216 to 217 of 1000
# Time step from 217 to 218 of 1000
# Time step from 218 to 219 of 1000
# Time step from 219 to 220 of 1000
# Writing step 220 to file
# Time step from 220 to 221 of 1000
# Time step from 221 to 222 of 1000
# Time step from 222 to 223 of 1000
# Time step from 223 to 224 of 1000
# Time step from 224 to 225 of 1000
# Time step from 225 to 226 of 1000
# Time step from 226 to 227 of 1000
# Time step from 227 to 228 of 1000
# Time step from 228 to 229 of 1000
# Time step from 229 to 230 of 1000
# Writing step 230 to file
# Time step from 230 to 231 of 1000
# Time step from 231 to 232 of 1000
# Time step from 232 to 233 of 1000
# Time step from 233 to 234 of 1000
# Time step from 234 to 235 of 1000
# Time step from 235 to 236 of 1000
# Time step from 236 to 237 of 1000
# Time step from 237 to 238 of 1000
# Time step from 238 to 239 of 1000
# Time step from 239 to 240 of 1000
# Writing step 240 to file
# Time step from 240 to 241 of 1000
# Time step from 241 to 242 of 1000
# Time step from 242 to 243 of 1000
# Time step from 243 to 244 of 1000
# Time step from 244 to 245 of 1000
# Time step from 245 to 246 of 1000
# Time step from 246 to 247 of 1000
# Time step from 247 to 248 of 1000
# Time step from 248 to 249 of 1000
# Time step from 249 to 250 of 1000
# Writing step 250 to file
# Time step from 250 to 251 of 1000
# Time step from 251 to 252 of 1000
# Time step from 252 to 253 of 1000
# Time step from 253 to 254 of 1000
# Time step from 254 to 255 of 1000
# Time step from 255 to 256 of 1000
# Time step from 256 to 257 of 1000
# Time step from 257 to 258 of 1000
# Time step from 258 to 259 of 1000
# Time step from 259 to 260 of 1000
# Writing step 260 to file
# Time step from 260 to 261 of 1000
# Time step from 261 to 262 of 1000
# Time step from 262 to 263 of 1000
# Time step from 263 to 264 of 1000
# Time step from 264 to 265 of 1000
# Time step from 265 to 266 of 1000
# Time step from 266 to 267 of 1000
# Time step from 267 to 268 of 1000
# Time step from 268 to 269 of 1000
# Time step from 269 to 270 of 1000
# Writing step 270 to file
# Time step from 270 to 271 of 1000
# Time step from 271 to 272 of 1000
# Time step from 272 to 273 of 1000
# Time step from 273 to 274 of 1000
# Time step from 274 to 275 of 1000
# Time step from 275 to 276 of 1000
# Time step from 276 to 277 of 1000
# Time step from 277 to 278 of 1000
# Time step from 278 to 279 of 1000
# Time step from 279 to 280 of 1000
# Writing step 280 to file
# Time step from 280 to 281 of 1000
# Time step from 281 to 282 of 1000
# Time step from 282 to 283 of 1000
# Time step from 283 to 284 of 1000
# Time step from 284 to 285 of 1000
# Time step from 285 to 286 of 1000
# Time step from 286 to 287 of 1000
# Time step from 287 to 288 of 1000
# Time step from 288 to 289 of 1000
# Time step from 289 to 290 of 1000
# Writing step 290 to file
# Time step from 290 to 291 of 1000
# Time step from 291 to 292 of 1000
# Time step from 292 to 293 of 1000
# Time step from 293 to 294 of 1000
# Time step from 294 to 295 of 1000
# Time step from 295 to 296 of 1000
# Time step from 296 to 297 of 1000
# Time step from 297 to 298 of 1000
# Time step from 298 to 299 of 1000
# Time step from 299 to 300 of 1000
# Writing step 300 to file
# Time step from 300 to 301 of 1000
# Time step from 301 to 302 of 1000
# Time step from 302 to 303 of 1000
# Time step from 303 to 304 of 1000
# Time step from 304 to 305 of 1000
# Time step from 305 to 306 of 1000
# Time step from 306 to 307 of 1000
# Time step from 307 to 308 of 1000
# Time step from 308 to 309 of 1000
# Time step from 309 to 310 of 1000
# Writing step 310 to file
# Time step from 310 to 311 of 1000
# Time step from 311 to 312 of 1000
# Time step from 312 to 313 of 1000
# Time step from 313 to 314 of 1000
# Time step from 314 to 315 of 1000
# Time step from 315 to 316 of 1000
# Time step from 316 to 317 of 1000
# Time step from 317 to 318 of 1000
# Time step from 318 to 319 of 1000
# Time step from 319 to 320 of 1000
# Writing step 320 to file
# Time step from 320 to 321 of 1000
# Time step from 321 to 322 of 1000
# Time step from 322 to 323 of 1000
# Time step from 323 to 324 of 1000
# Time step from 324 to 325 of 1000
# Time step from 325 to 326 of 1000
# Time step from 326 to 327 of 1000
# Time step from 327 to 328 of 1000
# Time step from 328 to 329 of 1000
# Time step from 329 to 330 of 1000
# Writing step 330 to file
# Time step from 330 to 331 of 1000
# Time step from 331 to 332 of 1000
# Time step from 332 to 333 of 1000
# Time step from 333 to 334 of 1000
# Time step from 334 to 335 of 1000
# Time step from 335 to 336 of 1000
# Time step from 336 to 337 of 1000
# Time step from 337 to 338 of 1000
# Time step from 338 to 339 of 1000
# Time step from 339 to 340 of 1000
# Writing step 340 to file
# Time step from 340 to 341 of 1000
# Time step from 341 to 342 of 1000
# Time step from 342 to 343 of 1000
# Time step from 343 to 344 of 1000
# Time step from 344 to 345 of 1000
# Time step from 345 to 346 of 1000
# Time step from 346 to 347 of 1000
# Time step from 347 to 348 of 1000
# Time step from 348 to 349 of 1000
# Time step from 349 to 350 of 1000
# Writing step 350 to file
# Time step from 350 to 351 of 1000
# Time step from 351 to 352 of 1000
# Time step from 352 to 353 of 1000
# Time step from 353 to 354 of 1000
# Time step from 354 to 355 of 1000
# Time step from 355 to 356 of 1000
# Time step from 356 to 357 of 1000
# Time step from 357 to 358 of 1000
# Time step from 358 to 359 of 1000
# Time step from 359 to 360 of 1000
# Writing step 360 to file
# Time step from 360 to 361 of 1000
# Time step from 361 to 362 of 1000
# Time step from 362 to 363 of 1000
# Time step from 363 to 364 of 1000
# Time step from 364 to 365 of 1000
# Time step from 365 to 366 of 1000
# Time step from 366 to 367 of 1000
# Time step from 367 to 368 of 1000
# Time step from 368 to 369 of 1000
# Time step from 369 to 370 of 1000
# Writing step 370 to file
# Time step from 370 to 371 of 1000
# Time step from 371 to 372 of 1000
# Time step from 372 to 373 of 1000
# Time step from 373 to 374 of 1000
# Time step from 374 to 375 of 1000
# Time step from 375 to 376 of 1000
# Time step from 376 to 377 of 1000
# Time step from 377 to 378 of 1000
# Time step from 378 to 379 of 1000
# Time step from 379 to 380 of 1000
# Writing step 380 to file
# Time step from 380 to 381 of 1000
# Time step from 381 to 382 of 1000
# Time step from 382 to 383 of 1000
# Time step from 383 to 384 of 1000
# Time step from 384 to 385 of 1000
# Time step from 385 to 386 of 1000
# Time step from 386 to 387 of 1000
# Time step from 387 to 388 of 1000
# Time step from 388 to 389 of 1000
# Time step from 389 to 390 of 1000
# Writing step 390 to file
# Time step from 390 to 391 of 1000
# Time step from 391 to 392 of 1000
# Time step from 392 to 393 of 1000
# Time step from 393 to 394 of 1000
# Time step from 394 to 395 of 1000
# Time step from 395 to 396 of 1000
# Time step from 396 to 397 of 1000
# Time step from 397 to 398 of 1000
# Time step from 398 to 399 of 1000
# Time step from 399 to 400 of 1000
# Writing step 400 to file
# Time step from 400 to 401 of 1000
# Time step from 401 to 402 of 1000
# Time step from 402 to 403 of 1000
# Time step from 403 to 404 of 1000
# Time step from 404 to 405 of 1000
# Time step from 405 to 406 of 1000
# Time step from 406 to 407 of 1000
# Time step from 407 to 408 of 1000
# Time step from 408 to 409 of 1000
# Time step from 409 to 410 of 1000
# Writing step 410 to file
# Time step from 410 to 411 of 1000
# Time step from 411 to 412 of 1000
# Time step from 412 to 413 of 1000
# Time step from 413 to 414 of 1000
# Time step from 414 to 415 of 1000
# Time step from 415 to 416 of 1000
# Time step from 416 to 417 of 1000
# Time step from 417 to 418 of 1000
# Time step from 418 to 419 of 1000
# Time step from 419 to 420 of 1000
# Writing step 420 to file
# Time step from 420 to 421 of 1000
# Time step from 421 to 422 of 1000
# Time step from 422 to 423 of 1000
# Time step from 423 to 424 of 1000
# Time step from 424 to 425 of 1000
# Time step from 425 to 426 of 1000
# Time step from 426 to 427 of 1000
# Time step from 427 to 428 of 1000
# Time step from 428 to 429 of 1000
# Time step from 429 to 430 of 1000
# Writing step 430 to file
# Time step from 430 to 431 of 1000
# Time step from 431 to 432 of 1000
# Time step from 432 to 433 of 1000
# Time step from 433 to 434 of 1000
# Time step from 434 to 435 of 1000
# Time step from 435 to 436 of 1000
# Time step from 436 to 437 of 1000
# Time step from 437 to 438 of 1000
# Time step from 438 to 439 of 1000
# Time step from 439 to 440 of 1000
# Writing step 440 to file
# Time step from 440 to 441 of 1000
# Time step from 441 to 442 of 1000
# Time step from 442 to 443 of 1000
# Time step from 443 to 444 of 1000
# Time step from 444 to 445 of 1000
# Time step from 445 to 446 of 1000
# Time step from 446 to 447 of 1000
# Time step from 447 to 448 of 1000
# Time step from 448 to 449 of 1000
# Time step from 449 to 450 of 1000
# Writing step 450 to file
# Time step from 450 to 451 of 1000
# Time step from 451 to 452 of 1000
# Time step from 452 to 453 of 1000
# Time step from 453 to 454 of 1000
# Time step from 454 to 455 of 1000
# Time step from 455 to 456 of 1000
# Time step from 456 to 457 of 1000
# Time step from 457 to 458 of 1000
# Time step from 458 to 459 of 1000
# Time step from 459 to 460 of 1000
# Writing step 460 to file
# Time step from 460 to 461 of 1000
# Time step from 461 to 462 of 1000
# Time step from 462 to 463 of 1000
# Time step from 463 to 464 of 1000
# Time step from 464 to 465 of 1000
# Time step from 465 to 466 of 1000
# Time step from 466 to 467 of 1000
# Time step from 467 to 468 of 1000
# Time step from 468 to 469 of 1000
# Time step from 469 to 470 of 1000
# Writing step 470 to file
# Time step from 470 to 471 of 1000
# Time step from 471 to 472 of 1000
# Time step from 472 to 473 of 1000
# Time step from 473 to 474 of 1000
# Time step from 474 to 475 of 1000
# Time step from 475 to 476 of 1000
# Time step from 476 to 477 of 1000
# Time step from 477 to 478 of 1000
# Time step from 478 to 479 of 1000
# Time step from 479 to 480 of 1000
# Writing step 480 to file
# Time step from 480 to 481 of 1000
# Time step from 481 to 482 of 1000
# Time step from 482 to 483 of 1000
# Time step from 483 to 484 of 1000
# Time step from 484 to 485 of 1000
# Time step from 485 to 486 of 1000
# Time step from 486 to 487 of 1000
# Time step from 487 to 488 of 1000
# Time step from 488 to 489 of 1000
# Time step from 489 to 490 of 1000
# Writing step 490 to file
# Time step from 490 to 491 of 1000
# Time step from 491 to 492 of 1000
# Time step from 492 to 493 of 1000
# Time step from 493 to 494 of 1000
# Time step from 494 to 495 of 1000
# Time step from 495 to 496 of 1000
# Time step from 496 to 497 of 1000
# Time step from 497 to 498 of 1000
# Time step from 498 to 499 of 1000
# Time step from 499 to 500 of 1000
# Writing step 500 to file
# Time step from 500 to 501 of 1000
# Time step from 501 to 502 of 1000
# Time step from 502 to 503 of 1000
# Time step from 503 to 504 of 1000
# Time step from 504 to 505 of 1000
# Time step from 505 to 506 of 1000
# Time step from 506 to 507 of 1000
# Time step from 507 to 508 of 1000
# Time step from 508 to 509 of 1000
# Time step from 509 to 510 of 1000
# Writing step 510 to file
# Time step from 510 to 511 of 1000
# Time step from 511 to 512 of 1000
# Time step from 512 to 513 of 1000
# Time step from 513 to 514 of 1000
# Time step from 514 to 515 of 1000
# Time step from 515 to 516 of 1000
# Time step from 516 to 517 of 1000
# Time step from 517 to 518 of 1000
# Time step from 518 to 519 of 1000
# Time step from 519 to 520 of 1000
# Writing step 520 to file
# Time step from 520 to 521 of 1000
# Time step from 521 to 522 of 1000
# Time step from 522 to 523 of 1000
# Time step from 523 to 524 of 1000
# Time step from 524 to 525 of 1000
# Time step from 525 to 526 of 1000
# Time step from 526 to 527 of 1000
# Time step from 527 to 528 of 1000
# Time step from 528 to 529 of 1000
# Time step from 529 to 530 of 1000
# Writing step 530 to file
# Time step from 530 to 531 of 1000
# Time step from 531 to 532 of 1000
# Time step from 532 to 533 of 1000
# Time step from 533 to 534 of 1000
# Time step from 534 to 535 of 1000
# Time step from 535 to 536 of 1000
# Time step from 536 to 537 of 1000
# Time step from 537 to 538 of 1000
# Time step from 538 to 539 of 1000
# Time step from 539 to 540 of 1000
# Writing step 540 to file
# Time step from 540 to 541 of 1000
# Time step from 541 to 542 of 1000
# Time step from 542 to 543 of 1000
# Time step from 543 to 544 of 1000
# Time step from 544 to 545 of 1000
# Time step from 545 to 546 of 1000
# Time step from 546 to 547 of 1000
# Time step from 547 to 548 of 1000
# Time step from 548 to 549 of 1000
# Time step from 549 to 550 of 1000
# Writing step 550 to file
# Time step from 550 to 551 of 1000
# Time step from 551 to 552 of 1000
# Time step from 552 to 553 of 1000
# Time step from 553 to 554 of 1000
# Time step from 554 to 555 of 1000
# Time step from 555 to 556 of 1000
# Time step from 556 to 557 of 1000
# Time step from 557 to 558 of 1000
# Time step from 558 to 559 of 1000
# Time step from 559 to 560 of 1000
# Writing step 560 to file
# Time step from 560 to 561 of 1000
# Time step from 561 to 562 of 1000
# Time step from 562 to 563 of 1000
# Time step from 563 to 564 of 1000
# Time step from 564 to 565 of 1000
# Time step from 565 to 566 of 1000
# Time step from 566 to 567 of 1000
# Time step from 567 to 568 of 1000
# Time step from 568 to 569 of 1000
# Time step from 569 to 570 of 1000
# Writing step 570 to file
# Time step from 570 to 571 of 1000
# Time step from 571 to 572 of 1000
# Time step from 572 to 573 of 1000
# Time step from 573 to 574 of 1000
# Time step from 574 to 575 of 1000
# Time step from 575 to 576 of 1000
# Time step from 576 to 577 of 1000
# Time step from 577 to 578 of 1000
# Time step from 578 to 579 of 1000
# Time step from 579 to 580 of 1000
# Writing step 580 to file
# Time step from 580 to 581 of 1000
# Time step from 581 to 582 of 1000
# Time step from 582 to 583 of 1000
# Time step from 583 to 584 of 1000
# Time step from 584 to 585 of 1000
# Time step from 585 to 586 of 1000
# Time step from 586 to 587 of 1000
# Time step from 587 to 588 of 1000
# Time step from 588 to 589 of 1000
# Time step from 589 to 590 of 1000
# Writing step 590 to file
# Time step from 590 to 591 of 1000
# Time step from 591 to 592 of 1000
# Time step from 592 to 593 of 1000
# Time step from 593 to 594 of 1000
# Time step from 594 to 595 of 1000
# Time step from 595 to 596 of 1000
# Time step from 596 to 597 of 1000
# Time step from 597 to 598 of 1000
# Time step from 598 to 599 of 1000
# Time step from 599 to 600 of 1000
# Writing step 600 to file
# Time step from 600 to 601 of 1000
# Time step from 601 to 602 of 1000
# Time step from 602 to 603 of 1000
# Time step from 603 to 604 of 1000
# Time step from 604 to 605 of 1000
# Time step from 605 to 606 of 1000
# Time step from 606 to 607 of 1000
# Time step from 607 to 608 of 1000
# Time step from 608 to 609 of 1000
# Time step from 609 to 610 of 1000
# Writing step 610 to file
# Time step from 610 to 611 of 1000
# Time step from 611 to 612 of 1000
# Time step from 612 to 613 of 1000
# Time step from 613 to 614 of 1000
# Time step from 614 to 615 of 1000
# Time step from 615 to 616 of 1000
# Time step from 616 to 617 of 1000
# Time step from 617 to 618 of 1000
# Time step from 618 to 619 of 1000
# Time step from 619 to 620 of 1000
# Writing step 620 to file
# Time step from 620 to 621 of 1000
# Time step from 621 to 622 of 1000
# Time step from 622 to 623 of 1000
# Time step from 623 to 624 of 1000
# Time step from 624 to 625 of 1000
# Time step from 625 to 626 of 1000
# Time step from 626 to 627 of 1000
# Time step from 627 to 628 of 1000
# Time step from 628 to 629 of 1000
# Time step from 629 to 630 of 1000
# Writing step 630 to file
# Time step from 630 to 631 of 1000
# Time step from 631 to 632 of 1000
# Time step from 632 to 633 of 1000
# Time step from 633 to 634 of 1000
# Time step from 634 to 635 of 1000
# Time step from 635 to 636 of 1000
# Time step from 636 to 637 of 1000
# Time step from 637 to 638 of 1000
# Time step from 638 to 639 of 1000
# Time step from 639 to 640 of 1000
# Writing step 640 to file
# Time step from 640 to 641 of 1000
# Time step from 641 to 642 of 1000
# Time step from 642 to 643 of 1000
# Time step from 643 to 644 of 1000
# Time step from 644 to 645 of 1000
# Time step from 645 to 646 of 1000
# Time step from 646 to 647 of 1000
# Time step from 647 to 648 of 1000
# Time step from 648 to 649 of 1000
# Time step from 649 to 650 of 1000
# Writing step 650 to file
# Time step from 650 to 651 of 1000
# Time step from 651 to 652 of 1000
# Time step from 652 to 653 of 1000
# Time step from 653 to 654 of 1000
# Time step from 654 to 655 of 1000
# Time step from 655 to 656 of 1000
# Time step from 656 to 657 of 1000
# Time step from 657 to 658 of 1000
# Time step from 658 to 659 of 1000
# Time step from 659 to 660 of 1000
# Writing step 660 to file
# Time step from 660 to 661 of 1000
# Time step from 661 to 662 of 1000
# Time step from 662 to 663 of 1000
# Time step from 663 to 664 of 1000
# Time step from 664 to 665 of 1000
# Time step from 665 to 666 of 1000
# Time step from 666 to 667 of 1000
# Time step from 667 to 668 of 1000
# Time step from 668 to 669 of 1000
# Time step from 669 to 670 of 1000
# Writing step 670 to file
# Time step from 670 to 671 of 1000
# Time step from 671 to 672 of 1000
# Time step from 672 to 673 of 1000
# Time step from 673 to 674 of 1000
# Time step from 674 to 675 of 1000
# Time step from 675 to 676 of 1000
# Time step from 676 to 677 of 1000
# Time step from 677 to 678 of 1000
# Time step from 678 to 679 of 1000
# Time step from 679 to 680 of 1000
# Writing step 680 to file
# Time step from 680 to 681 of 1000
# Time step from 681 to 682 of 1000
# Time step from 682 to 683 of 1000
# Time step from 683 to 684 of 1000
# Time step from 684 to 685 of 1000
# Time step from 685 to 686 of 1000
# Time step from 686 to 687 of 1000
# Time step from 687 to 688 of 1000
# Time step from 688 to 689 of 1000
# Time step from 689 to 690 of 1000
# Writing step 690 to file
# Time step from 690 to 691 of 1000
# Time step from 691 to 692 of 1000
# Time step from 692 to 693 of 1000
# Time step from 693 to 694 of 1000
# Time step from 694 to 695 of 1000
# Time step from 695 to 696 of 1000
# Time step from 696 to 697 of 1000
# Time step from 697 to 698 of 1000
# Time step from 698 to 699 of 1000
# Time step from 699 to 700 of 1000
# Writing step 700 to file
# Time step from 700 to 701 of 1000
# Time step from 701 to 702 of 1000
# Time step from 702 to 703 of 1000
# Time step from 703 to 704 of 1000
# Time step from 704 to 705 of 1000
# Time step from 705 to 706 of 1000
# Time step from 706 to 707 of 1000
# Time step from 707 to 708 of 1000
# Time step from 708 to 709 of 1000
# Time step from 709 to 710 of 1000
# Writing step 710 to file
# Time step from 710 to 711 of 1000
# Time step from 711 to 712 of 1000
# Time step from 712 to 713 of 1000
# Time step from 713 to 714 of 1000
# Time step from 714 to 715 of 1000
# Time step from 715 to 716 of 1000
# Time step from 716 to 717 of 1000
# Time step from 717 to 718 of 1000
# Time step from 718 to 719 of 1000
# Time step from 719 to 720 of 1000
# Writing step 720 to file
# Time step from 720 to 721 of 1000
# Time step from 721 to 722 of 1000
# Time step from 722 to 723 of 1000
# Time step from 723 to 724 of 1000
# Time step from 724 to 725 of 1000
# Time step from 725 to 726 of 1000
# Time step from 726 to 727 of 1000
# Time step from 727 to 728 of 1000
# Time step from 728 to 729 of 1000
# Time step from 729 to 730 of 1000
# Writing step 730 to file
# Time step from 730 to 731 of 1000
# Time step from 731 to 732 of 1000
# Time step from 732 to 733 of 1000
# Time step from 733 to 734 of 1000
# Time step from 734 to 735 of 1000
# Time step from 735 to 736 of 1000
# Time step from 736 to 737 of 1000
# Time step from 737 to 738 of 1000
# Time step from 738 to 739 of 1000
# Time step from 739 to 740 of 1000
# Writing step 740 to file
# Time step from 740 to 741 of 1000
# Time step from 741 to 742 of 1000
# Time step from 742 to 743 of 1000
# Time step from 743 to 744 of 1000
# Time step from 744 to 745 of 1000
# Time step from 745 to 746 of 1000
# Time step from 746 to 747 of 1000
# Time step from 747 to 748 of 1000
# Time step from 748 to 749 of 1000
# Time step from 749 to 750 of 1000
# Writing step 750 to file
# Time step from 750 to 751 of 1000
# Time step from 751 to 752 of 1000
# Time step from 752 to 753 of 1000
# Time step from 753 to 754 of 1000
# Time step from 754 to 755 of 1000
# Time step from 755 to 756 of 1000
# Time step from 756 to 757 of 1000
# Time step from 757 to 758 of 1000
# Time step from 758 to 759 of 1000
# Time step from 759 to 760 of 1000
# Writing step 760 to file
# Time step from 760 to 761 of 1000
# Time step from 761 to 762 of 1000
# Time step from 762 to 763 of 1000
# Time step from 763 to 764 of 1000
# Time step from 764 to 765 of 1000
# Time step from 765 to 766 of 1000
# Time step from 766 to 767 of 1000
# Time step from 767 to 768 of 1000
# Time step from 768 to 769 of 1000
# Time step from 769 to 770 of 1000
# Writing step 770 to file
# Time step from 770 to 771 of 1000
# Time step from 771 to 772 of 1000
# Time step from 772 to 773 of 1000
# Time step from 773 to 774 of 1000
# Time step from 774 to 775 of 1000
# Time step from 775 to 776 of 1000
# Time step from 776 to 777 of 1000
# Time step from 777 to 778 of 1000
# Time step from 778 to 779 of 1000
# Time step from 779 to 780 of 1000
# Writing step 780 to file
# Time step from 780 to 781 of 1000
# Time step from 781 to 782 of 1000
# Time step from 782 to 783 of 1000
# Time step from 783 to 784 of 1000
# Time step from 784 to 785 of 1000
# Time step from 785 to 786 of 1000
# Time step from 786 to 787 of 1000
# Time step from 787 to 788 of 1000
# Time step from 788 to 789 of 1000
# Time step from 789 to 790 of 1000
# Writing step 790 to file
# Time step from 790 to 791 of 1000
# Time step from 791 to 792 of 1000
# Time step from 792 to 793 of 1000
# Time step from 793 to 794 of 1000
# Time step from 794 to 795 of 1000
# Time step from 795 to 796 of 1000
# Time step from 796 to 797 of 1000
# Time step from 797 to 798 of 1000
# Time step from 798 to 799 of 1000
# Time step from 799 to 800 of 1000
# Writing step 800 to file
# Time step from 800 to 801 of 1000
# Time step from 801 to 802 of 1000
# Time step from 802 to 803 of 1000
# Time step from 803 to 804 of 1000
# Time step from 804 to 805 of 1000
# Time step from 805 to 806 of 1000
# Time step from 806 to 807 of 1000
# Time step from 807 to 808 of 1000
# Time step from 808 to 809 of 1000
# Time step from 809 to 810 of 1000
# Writing step 810 to file
# Time step from 810 to 811 of 1000
# Time step from 811 to 812 of 1000
# Time step from 812 to 813 of 1000
# Time step from 813 to 814 of 1000
# Time step from 814 to 815 of 1000
# Time step from 815 to 816 of 1000
# Time step from 816 to 817 of 1000
# Time step from 817 to 818 of 1000
# Time step from 818 to 819 of 1000
# Time step from 819 to 820 of 1000
# Writing step 820 to file
# Time step from 820 to 821 of 1000
# Time step from 821 to 822 of 1000
# Time step from 822 to 823 of 1000
# Time step from 823 to 824 of 1000
# Time step from 824 to 825 of 1000
# Time step from 825 to 826 of 1000
# Time step from 826 to 827 of 1000
# Time step from 827 to 828 of 1000
# Time step from 828 to 829 of 1000
# Time step from 829 to 830 of 1000
# Writing step 830 to file
# Time step from 830 to 831 of 1000
# Time step from 831 to 832 of 1000
# Time step from 832 to 833 of 1000
# Time step from 833 to 834 of 1000
# Time step from 834 to 835 of 1000
# Time step from 835 to 836 of 1000
# Time step from 836 to 837 of 1000
# Time step from 837 to 838 of 1000
# Time step from 838 to 839 of 1000
# Time step from 839 to 840 of 1000
# Writing step 840 to file
# Time step from 840 to 841 of 1000
# Time step from 841 to 842 of 1000
# Time step from 842 to 843 of 1000
# Time step from 843 to 844 of 1000
# Time step from 844 to 845 of 1000
# Time step from 845 to 846 of 1000
# Time step from 846 to 847 of 1000
# Time step from 847 to 848 of 1000
# Time step from 848 to 849 of 1000
# Time step from 849 to 850 of 1000
# Writing step 850 to file
# Time step from 850 to 851 of 1000
# Time step from 851 to 852 of 1000
# Time step from 852 to 853 of 1000
# Time step from 853 to 854 of 1000
# Time step from 854 to 855 of 1000
# Time step from 855 to 856 of 1000
# Time step from 856 to 857 of 1000
# Time step from 857 to 858 of 1000
# Time step from 858 to 859 of 1000
# Time step from 859 to 860 of 1000
# Writing step 860 to file
# Time step from 860 to 861 of 1000
# Time step from 861 to 862 of 1000
# Time step from 862 to 863 of 1000
# Time step from 863 to 864 of 1000
# Time step from 864 to 865 of 1000
# Time step from 865 to 866 of 1000
# Time step from 866 to 867 of 1000
# Time step from 867 to 868 of 1000
# Time step from 868 to 869 of 1000
# Time step from 869 to 870 of 1000
# Writing step 870 to file
# Time step from 870 to 871 of 1000
# Time step from 871 to 872 of 1000
# Time step from 872 to 873 of 1000
# Time step from 873 to 874 of 1000
# Time step from 874 to 875 of 1000
# Time step from 875 to 876 of 1000
# Time step from 876 to 877 of 1000
# Time step from 877 to 878 of 1000
# Time step from 878 to 879 of 1000
# Time step from 879 to 880 of 1000
# Writing step 880 to file
# Time step from 880 to 881 of 1000
# Time step from 881 to 882 of 1000
# Time step from 882 to 883 of 1000
# Time step from 883 to 884 of 1000
# Time step from 884 to 885 of 1000
# Time step from 885 to 886 of 1000
# Time step from 886 to 887 of 1000
# Time step from 887 to 888 of 1000
# Time step from 888 to 889 of 1000
# Time step from 889 to 890 of 1000
# Writing step 890 to file
# Time step from 890 to 891 of 1000
# Time step from 891 to 892 of 1000
# Time step from 892 to 893 of 1000
# Time step from 893 to 894 of 1000
# Time step from 894 to 895 of 1000
# Time step from 895 to 896 of 1000
# Time step from 896 to 897 of 1000
# Time step from 897 to 898 of 1000
# Time step from 898 to 899 of 1000
# Time step from 899 to 900 of 1000
# Writing step 900 to file
# Time step from 900 to 901 of 1000
# Time step from 901 to 902 of 1000
# Time step from 902 to 903 of 1000
# Time step from 903 to 904 of 1000
# Time step from 904 to 905 of 1000
# Time step from 905 to 906 of 1000
# Time step from 906 to 907 of 1000
# Time step from 907 to 908 of 1000
# Time step from 908 to 909 of 1000
# Time step from 909 to 910 of 1000
# Writing step 910 to file
# Time step from 910 to 911 of 1000
# Time step from 911 to 912 of 1000
# Time step from 912 to 913 of 1000
# Time step from 913 to 914 of 1000
# Time step from 914 to 915 of 1000
# Time step from 915 to 916 of 1000
# Time step from 916 to 917 of 1000
# Time step from 917 to 918 of 1000
# Time step from 918 to 919 of 1000
# Time step from 919 to 920 of 1000
# Writing step 920 to file
# Time step from 920 to 921 of 1000
# Time step from 921 to 922 of 1000
# Time step from 922 to 923 of 1000
# Time step from 923 to 924 of 1000
# Time step from 924 to 925 of 1000
# Time step from 925 to 926 of 1000
# Time step from 926 to 927 of 1000
# Time step from 927 to 928 of 1000
# Time step from 928 to 929 of 1000
# Time step from 929 to 930 of 1000
# Writing step 930 to file
# Time step from 930 to 931 of 1000
# Time step from 931 to 932 of 1000
# Time step from 932 to 933 of 1000
# Time step from 933 to 934 of 1000
# Time step from 934 to 935 of 1000
# Time step from 935 to 936 of 1000
# Time step from 936 to 937 of 1000
# Time step from 937 to 938 of 1000
# Time step from 938 to 939 of 1000
# Time step from 939 to 940 of 1000
# Writing step 940 to file
# Time step from 940 to 941 of 1000
# Time step from 941 to 942 of 1000
# Time step from 942 to 943 of 1000
# Time step from 943 to 944 of 1000
# Time step from 944 to 945 of 1000
# Time step from 945 to 946 of 1000
# Time step from 946 to 947 of 1000
# Time step from 947 to 948 of 1000
# Time step from 948 to 949 of 1000
# Time step from 949 to 950 of 1000
# Writing step 950 to file
# Time step from 950 to 951 of 1000
# Time step from 951 to 952 of 1000
# Time step from 952 to 953 of 1000
# Time step from 953 to 954 of 1000
# Time step from 954 to 955 of 1000
# Time step from 955 to 956 of 1000
# Time step from 956 to 957 of 1000
# Time step from 957 to 958 of 1000
# Time step from 958 to 959 of 1000
# Time step from 959 to 960 of 1000
# Writing step 960 to file
# Time step from 960 to 961 of 1000
# Time step from 961 to 962 of 1000
# Time step from 962 to 963 of 1000
# Time step from 963 to 964 of 1000
# Time step from 964 to 965 of 1000
# Time step from 965 to 966 of 1000
# Time step from 966 to 967 of 1000
# Time step from 967 to 968 of 1000
# Time step from 968 to 969 of 1000
# Time step from 969 to 970 of 1000
# Writing step 970 to file
# Time step from 970 to 971 of 1000
# Time step from 971 to 972 of 1000
# Time step from 972 to 973 of 1000
# Time step from 973 to 974 of 1000
# Time step from 974 to 975 of 1000
# Time step from 975 to 976 of 1000
# Time step from 976 to 977 of 1000
# Time step from 977 to 978 of 1000
# Time step from 978 to 979 of 1000
# Time step from 979 to 980 of 1000
# Writing step 980 to file
# Time step from 980 to 981 of 1000
# Time step from 981 to 982 of 1000
# Time step from 982 to 983 of 1000
# Time step from 983 to 984 of 1000
# Time step from 984 to 985 of 1000
# Time step from 985 to 986 of 1000
# Time step from 986 to 987 of 1000
# Time step from 987 to 988 of 1000
# Time step from 988 to 989 of 1000
# Time step from 989 to 990 of 1000
# Writing step 990 to file
# Time step from 990 to 991 of 1000
# Time step from 991 to 992 of 1000
# Time step from 992 to 993 of 1000
# Time step from 993 to 994 of 1000
# Time step from 994 to 995 of 1000
# Time step from 995 to 996 of 1000
# Time step from 996 to 997 of 1000
# Time step from 997 to 998 of 1000
# Time step from 998 to 999 of 1000
# Time step from 999 to 1000 of 1000
# Writing step 1000 to file

# %%
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 

fname = "single_particle_in_radial_el_field_history.h5"
with h5py.File(fname, mode="r") as h5:
    t = np.array(h5['/time'])
    p = np.array(h5['/particles/position'][0])
    m = np.array(h5['/particles/momentum'][0])
    M = float(h5['/particles/mass'][0])
    c = float(h5['/particles/charge'][0])
df = pd.DataFrame.from_dict({'time': t, 
                             'x': p[:, 0], 'y': p[:, 1], 'z': p[:, 2],
                             'px': m[:, 0], 'py': m[:, 1], 'pz': m[:, 2]})

p0 = p[0]
v0 = m[0]/M
r = 0.5
mom = m[0][1]
period = 2*pi*r/v0[1]
df['an_x'] = 2.5 + r * np.cos(2 * pi * t / period) 
df['an_y'] = 2.5 + r * np.sin(2 * pi * t / period) 
df['an_z'] = p0[2] + v0[2] * t
df['an_px'] = - mom * np.sin(2 * pi * t / period) 
df['an_py'] = mom * np.cos(2 * pi * t / period)
df['an_pz'] = m[0][2]
df['kinetic'] = (df.px**2 + df.py**2 + df.pz**2) / ( 2 * M )
df['an_kinetic'] = (df.an_px**2 + df.an_py**2 + df.an_pz**2) / ( 2 * M )
df['potential'] = df.apply(lambda row: pot_en(row['x'], row['y']), axis=1)
df['an_potential'] = df.apply(lambda row: pot_en(row['an_x'], row['an_y']), axis=1)
df['E'] = df.kinetic + df.potential
df['an_E'] = df.an_kinetic + df.an_potential
df.head()
# Out:
#            time         x         y         z            px            py  \
# 0  0.000000e+00  3.009243  2.500019  1.004580  2.221120e-20  2.743401e-18
# 1  3.000000e-11  3.002460  2.583631  1.009998 -4.202276e-19  2.710493e-18
# 2  6.000000e-11  2.982300  2.665017  1.015417 -8.508644e-19  2.605538e-18
# 3  9.000000e-11  2.949328  2.742021  1.020835 -1.257713e-18  2.431774e-18
# 4  1.200000e-10  2.904464  2.812620  1.026254 -1.629645e-18  2.194506e-18
#
#              pz      an_x      an_y      an_z         an_px         an_py  \
# 0  1.770000e-19  3.000000  2.500000  1.004580 -0.000000e+00  2.743401e-18
# 1  1.770000e-19  2.992964  2.583587  1.009999 -4.586271e-19  2.704794e-18
# 2  1.770000e-19  2.972053  2.664822  1.015417 -9.043459e-19  2.590059e-18
# 3  1.770000e-19  2.937856  2.741418  1.020835 -1.324612e-18  2.402426e-18
# 4  1.770000e-19  2.891335  2.811219  1.026254 -1.707596e-18  2.147176e-18
#
#           an_pz       kinetic    an_kinetic     potential  an_potential  \
# 0  1.770000e-19  3.856158e-09  3.855906e-09 -7.540601e-09 -7.680000e-09
# 1  1.770000e-19  3.854436e-09  3.855906e-09 -7.538693e-09 -7.680000e-09
# 2  1.770000e-19  3.849045e-09  3.855906e-09 -7.533123e-09 -7.680000e-09
# 3  1.770000e-19  3.840150e-09  3.855906e-09 -7.524060e-09 -7.680000e-09
# 4  1.770000e-19  3.828025e-09  3.855906e-09 -7.511783e-09 -7.680000e-09
#
#               E          an_E
# 0 -3.684443e-09 -3.824094e-09
# 1 -3.684257e-09 -3.824094e-09
# 2 -3.684079e-09 -3.824094e-09
# 3 -3.683910e-09 -3.824094e-09
# 4 -3.683757e-09 -3.824094e-09

# %%
def plot_3d(df):
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    ax.plot(df.x, df.z, df.y, 'b.', markersize = 12, label = "Num")
    ax.plot(df.an_x, df.an_z, df.an_y,  'g-', linewidth = 3, label = "An")
    ax.set_xlabel('X [cm]')
    ax.set_ylabel('Z [cm]')
    ax.set_zlabel('Y [cm]')
    plt.legend(loc = 'upper left', title="3d")
    plt.show()

plot_3d(df)

# %%
ax = df.plot.scatter(x='x', y='y', label="Num")
ax.legend(title="XY")
df.plot('an_x', 'an_y', ax=ax, label="An", color='red')
ax.set_xlabel('X [cm]')
ax.set_ylabel('X [cm]')
# Out:
# Text(0, 0.5, 'X [cm]')

# %%
ax = df.plot.scatter(x='z', y='x', label="Num")
ax.legend(title="ZX")
df.plot('an_z', 'an_x', ax=ax, label="An", color='red')
ax.set_xlabel('Z [cm]')
ax.set_ylabel('X [cm]')
# Out:
# Text(0, 0.5, 'X [cm]')

# %%
ax = df.plot.scatter(x='z', y='y', label="Num")
ax.legend(title="ZY")
df.plot('an_z', 'an_y', ax=ax, label="An", color='red')
ax.set_xlabel('Z [cm]')
ax.set_ylabel('YS [cm]')
# Out:
# Text(0, 0.5, 'YS [cm]')

# %%
ax = df.plot('time', ['E', 'an_E'], label=["Num", "An"])
ax.set_xlabel('time [s]')
ax.set_ylabel('E [erg]')
# Out:
# Text(0, 0.5, 'E [erg]')

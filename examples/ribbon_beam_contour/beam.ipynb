# %%
from math import *

# estimates are done in SI units;
# to compose config file, conversion to CGS is provided 

kg_to_g = 1000
coulomb_to_statcoulomb = 2997924580
m = 9.8e-31
q = 1.6e-19
print( "q = {:.3e} [C] = {:.3e} [statC]".format( q, q * coulomb_to_statcoulomb ) )
print( "m = {:.3e} [kg] = {:.3e} [g]".format( m, m * kg_to_g ) )

m_to_cm = 100
x_0 = 0.001
y_width = 0.03
print( "beam_width = {:.3f} [m] = {:.3f} [cm]".format( x_0, x_0 * m_to_cm ) )
print( "y_size = {:.3f} [m] = {:.3f} [cm]".format( y_width, y_width * m_to_cm ) )

I = 0.1
linear_current_density = I / y_width
print( "I = {:.3f} [A]".format( I ) )
print( "linear_current_density = {:.3f} [A/m]".format( linear_current_density ) )

voltage = 1000
q_electron = 1.60218e-19
ev_to_joule = 1.60218e-19
E = voltage * q / q_electron * ev_to_joule
v = sqrt( 2 * E / m )
print( "U = {:.3f} [V]".format( voltage ) )
print( "E = {:.3f} [eV]".format( E / ev_to_joule ) )
print( "v = {:.3e} [m/s]".format( v ) )

eps_0 = 8.85e-12
p = linear_current_density / ( 4 * eps_0 * sqrt( 2 * q / m ) * voltage**1.5 )
x0_2_times_wider = 2 * x_0
z_2_times_wider = sqrt( 2 * x_0 / p )
t_2_times_wider = z_2_times_wider / v
print( "x0_2_times_wider = {:.3f} [m] = {:.3f} [cm]".format(
    x0_2_times_wider, x0_2_times_wider * m_to_cm ) )
print( "t_2_times_wider = {:.3e} [s]".format( t_2_times_wider ) )
print( "z_2_times_wider = {:.3e} [m] = {:.3e} [cm]".format(
    z_2_times_wider, z_2_times_wider * m_to_cm ) )

sim_time = 3.0e-9
n_of_steps = 100
dt = sim_time / n_of_steps
print( "simulation_time = {:.3e} [s]".format( sim_time ) )
print( "number_of_time_steps = {:d}".format( n_of_steps ) )
print( "time_step_size = {:.3e} [s]".format( dt ) )

num_of_real_particles = I * dt / q
print( "num_of_real_particles = {:.3e}".format( num_of_real_particles ) )

num_of_macro_particles = 5000
macro_q = I * dt / num_of_macro_particles
macro_m = macro_q / q * m
macro_mean_momentum = macro_m * v
print( "num_of_macro_particles = {:d}".format( num_of_macro_particles ) )
print( "macro_q = {:.3e} [C] = {:.3e} [statC]".format(
    macro_q, macro_q * coulomb_to_statcoulomb ) )
print( "macro_m = {:.3e} [kg] = {:.3e} [g]".format( macro_m, macro_m * kg_to_g ) )
print( "macro_mean_momentum = {:.3e} [kg * m / s] = {:.3e} [g * cm / s]".format(
    macro_mean_momentum, macro_mean_momentum * m_to_cm * kg_to_g ) )

# %% [markdown]
# ## Config values are not exactly the same as estimates

# %%
from ef.config.config import Config
from ef.config.visualizer import Visualizer3d
sim = Config.from_fname('contour.conf')
sim.visualize_all(Visualizer3d())

# %%
# %%sh
# ef contour.conf
# Out:
# Config file is:  contour.conf
# [ TimeGrid ]
# total_time = 5.0e-9
# time_save_step = 5.0e-10
# time_step_size = 5.0e-11
# [ SpatialMesh ]
# grid_x_size = 0.5
# grid_x_step = 0.02
# grid_y_size = 2.0
# grid_y_step = 0.04
# grid_z_size = 8.0
# grid_z_step = 0.2
# [ ParticleSourceBox.cathode_emitter ]
# initial_number_of_particles = 5000
# particles_to_generate_each_step = 5000
# box_x_left = 0.275
# box_x_right = 0.225
# box_y_bottom = 0.6
# box_y_top = 1.4
# box_z_near = 0.11
# box_z_far = 0.12
# mean_momentum_x = 0
# mean_momentum_y = 0
# mean_momentum_z = 8.85e-17
# temperature = 0.0
# charge = -2.398e-08
# mass = 4.89e-26
# [ BoundaryConditions ]
# boundary_phi_left = 0.0
# boundary_phi_right = 0.0
# boundary_phi_bottom = 0.0
# boundary_phi_top = 0.0
# boundary_phi_near = 0.0
# boundary_phi_far = 0.0
# [ ParticleInteractionModel ]
# particle_interaction_model = PIC
# [ OutputFilename ]
# output_filename_prefix = contour_
# output_filename_suffix = .h5
# Writing initial fields to file
# Writing to file contour_fieldsWithoutParticles_new.h5
# Writing to file contour_fieldsWithoutParticles.h5
# Writing step 0 to file
# Writing to file contour_0000000_new.h5
# Writing to file contour_0000000.h5
# Time step from 0 to 1 of 100
# Time step from 1 to 2 of 100
# Time step from 2 to 3 of 100
# Time step from 3 to 4 of 100
# Time step from 4 to 5 of 100
# Time step from 5 to 6 of 100
# Time step from 6 to 7 of 100
# Time step from 7 to 8 of 100
# Time step from 8 to 9 of 100
# Time step from 9 to 10 of 100
# Writing step 10 to file
# Writing to file contour_0000010_new.h5
# Writing to file contour_0000010.h5
# Time step from 10 to 11 of 100
# Time step from 11 to 12 of 100
# Time step from 12 to 13 of 100
# Time step from 13 to 14 of 100
# Time step from 14 to 15 of 100
# Time step from 15 to 16 of 100
# Time step from 16 to 17 of 100
# Time step from 17 to 18 of 100
# Time step from 18 to 19 of 100
# Time step from 19 to 20 of 100
# Writing step 20 to file
# Writing to file contour_0000020_new.h5
# Writing to file contour_0000020.h5
# Time step from 20 to 21 of 100
# Time step from 21 to 22 of 100
# Time step from 22 to 23 of 100
# Time step from 23 to 24 of 100
# Time step from 24 to 25 of 100
# Time step from 25 to 26 of 100
# Time step from 26 to 27 of 100
# Time step from 27 to 28 of 100
# Time step from 28 to 29 of 100
# Time step from 29 to 30 of 100
# Writing step 30 to file
# Writing to file contour_0000030_new.h5
# Writing to file contour_0000030.h5
# Time step from 30 to 31 of 100
# Time step from 31 to 32 of 100
# Time step from 32 to 33 of 100
# Time step from 33 to 34 of 100
# Time step from 34 to 35 of 100
# Time step from 35 to 36 of 100
# Time step from 36 to 37 of 100
# Time step from 37 to 38 of 100
# Time step from 38 to 39 of 100
# Time step from 39 to 40 of 100
# Writing step 40 to file
# Writing to file contour_0000040_new.h5
# Writing to file contour_0000040.h5
# Time step from 40 to 41 of 100
# Time step from 41 to 42 of 100
# Time step from 42 to 43 of 100
# Time step from 43 to 44 of 100
# Time step from 44 to 45 of 100
# Time step from 45 to 46 of 100
# Time step from 46 to 47 of 100
# Time step from 47 to 48 of 100
# Time step from 48 to 49 of 100
# Time step from 49 to 50 of 100
# Writing step 50 to file
# Writing to file contour_0000050_new.h5
# Writing to file contour_0000050.h5
# Time step from 50 to 51 of 100
# Time step from 51 to 52 of 100
# Time step from 52 to 53 of 100
# Time step from 53 to 54 of 100
# Time step from 54 to 55 of 100
# Time step from 55 to 56 of 100
# Time step from 56 to 57 of 100
# Time step from 57 to 58 of 100
# Time step from 58 to 59 of 100
# Time step from 59 to 60 of 100
# Writing step 60 to file
# Writing to file contour_0000060_new.h5
# Writing to file contour_0000060.h5
# Time step from 60 to 61 of 100
# Time step from 61 to 62 of 100
# Time step from 62 to 63 of 100
# Time step from 63 to 64 of 100
# Time step from 64 to 65 of 100
# Time step from 65 to 66 of 100
# Time step from 66 to 67 of 100
# Time step from 67 to 68 of 100
# Time step from 68 to 69 of 100
# Time step from 69 to 70 of 100
# Writing step 70 to file
# Writing to file contour_0000070_new.h5
# Writing to file contour_0000070.h5
# Time step from 70 to 71 of 100
# Time step from 71 to 72 of 100
# Time step from 72 to 73 of 100
# Time step from 73 to 74 of 100
# Time step from 74 to 75 of 100
# Time step from 75 to 76 of 100
# Time step from 76 to 77 of 100
# Time step from 77 to 78 of 100
# Time step from 78 to 79 of 100
# Time step from 79 to 80 of 100
# Writing step 80 to file
# Writing to file contour_0000080_new.h5
# Writing to file contour_0000080.h5
# Time step from 80 to 81 of 100
# Time step from 81 to 82 of 100
# Time step from 82 to 83 of 100
# Time step from 83 to 84 of 100
# Time step from 84 to 85 of 100
# Time step from 85 to 86 of 100
# Time step from 86 to 87 of 100
# Time step from 87 to 88 of 100
# Time step from 88 to 89 of 100
# Time step from 89 to 90 of 100
# Writing step 90 to file
# Writing to file contour_0000090_new.h5
# Writing to file contour_0000090.h5
# Time step from 90 to 91 of 100
# Time step from 91 to 92 of 100
# Time step from 92 to 93 of 100
# Time step from 93 to 94 of 100
# Time step from 94 to 95 of 100
# Time step from 95 to 96 of 100
# Time step from 96 to 97 of 100
# Time step from 97 to 98 of 100
# Time step from 98 to 99 of 100
# Time step from 99 to 100 of 100
# Writing step 100 to file
# Writing to file contour_0000100_new.h5
# Writing to file contour_0000100.h5

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
from ef.simulation import Simulation

SGSE_conv_unit_current_to_A = 3e10 * 0.1;     #from current units SGSE to A
SI_conv_cm_to_m = 0.01;
SI_conv_g_to_kg = 0.001
SI_conv_Fr_to_C = 3.3356409519815207e-10

# %%
filename = 'contour_0000100_new.h5'
with h5py.File( filename, mode="r") as h5:
    sim = Simulation.init_from_h5(h5, 'contour_', '.h5')

# %%
particles_per_step = sim.particle_sources[0].particles_to_generate_each_step
current = np.abs(
    sim.particle_sources[0].particles_to_generate_each_step *
    sim.particle_sources[0].charge / 
    sim.time_grid.time_step_size
)
current = current / SGSE_conv_unit_current_to_A
print("source current = {} A".format(current))
# Out:
# source current = 0.0007993333333333333 A

# %%
mass = sim.particle_sources[0].mass * SI_conv_g_to_kg
charge = sim.particle_sources[0].charge * SI_conv_Fr_to_C
momentum_z = sim.particle_sources[0].mean_momentum[2] * SI_conv_g_to_kg * SI_conv_cm_to_m
print("mass = {} kg".format(mass))
print("charge = {} Coloumb".format(charge))
print("z-momentum = {} kg*m/s".format(momentum_z))
print("charge/mass = {:e} C/kg".format(charge/mass))
# Out:
# mass = 4.89e-29 kg
# charge = -7.998867002851687e-18 Coloumb
# z-momentum = 8.85e-22 kg*m/s
# charge/mass = -1.635760e+11 C/kg

# %%
length_of_cathode = sim.particle_sources[0].shape.size[1] * SI_conv_cm_to_m
half_width = sim.particle_sources[0].shape.size[0] / 2 * SI_conv_cm_to_m
center_of_beam = sim.particle_sources[0].shape.origin[0] * SI_conv_cm_to_m + half_width
print("lenghth of cathode (in y) = {} m".format(length_of_cathode))
print("half width of cathode (in x) = {} m".format(half_width))
print("center of beam (in x) = {} m".format(center_of_beam))
# Out:
# lenghth of cathode (in y) = 0.008 m
# half width of cathode (in x) = 0.0002500000000000001 m
# center of beam (in x) = 0.0025000000000000005 m

# %%
start_z = sim.particle_sources[0].shape.origin[2] * SI_conv_cm_to_m 
end_z = sim.spat_mesh.size[2] * SI_conv_cm_to_m
print("start of beam (in z) = {} m".format(start_z))
print("end of beam (in z) = {} m".format(end_z))
# Out:
# start of beam (in z) = 0.0011 m
# end of beam (in z) = 0.08 m

# %%
energy = (momentum_z * momentum_z) / (2 * mass)
voltage = energy / np.abs(charge)
print("voltage = {} V".format(voltage))
# Out:
# voltage = 1001.1962419136344 V

# %%
current_dens = current / length_of_cathode 
print("current density (along y) = {} A/m".format(current_dens))
# Out:
# current density (along y) = 0.09991666666666667 A/m

# %%
eps = 8.85e-12
p_const = 1 / (4*eps*(np.abs(2*charge/mass))**0.5) * current_dens / voltage**1.5 ;   
print("p constant = {}".format(p_const))
# Out:
# p constant = 0.15576900747253897

# %%
def contour(z_position, half_width, angle, p_const):
    y = half_width + np.tan(angle) * z_position + p_const / 2 * (z_position * z_position)         
    return y

conv_grad_to_rad = np.pi/180
angle = 0 * conv_grad_to_rad          #angle of beam
steps_z = 100000
position_z = np.arange(start_z,end_z,(end_z-start_z)/steps_z) 
# points in z direction, from 0 to 0.01 m with step 0,00001 m 

contour_y = contour(position_z, half_width, angle, p_const)
# countour calculation, m
plt.figure(figsize=(10,10), dpi = (100))
plt.xlabel("Z position, [mm]")
plt.ylabel("X position, [mm]")
plt.plot(sim.particle_arrays[0].positions[..., 2]*SI_conv_cm_to_m*1000,
         ((sim.particle_arrays[0].positions[..., 0]*SI_conv_cm_to_m - center_of_beam)*1000),
             'o',label="calculated_points") #plot particles

plt.plot(position_z*1000, contour_y*1000, color = 'g', lw = 3, label="analytic_curve") # plot countour in cm and move to left z of beam and top x of beam neat cathode
plt.plot(position_z*1000, -1 * contour_y*1000, color = 'g', lw = 3)
plt.legend(bbox_to_anchor=(0.32, 1), loc=1, borderaxespad=0.)
# plt.savefig('countour_beam.png')        # save png picture
# h5.close()                              #close h5 file

# %%
from math import *

# estimates are done in SI units;
# to compose config file, conversion to CGS is provided 

kg_to_g = 1000
coulomb_to_statcoulomb = 2997924580
m = 9.8e-31
q = 1.6e-19
print( "q = {:.3e} [C] = {:.3e} [statC]".format( q, q * coulomb_to_statcoulomb ) )
print( "m = {:.3e} [kg] = {:.3e} [g]".format( m, m * kg_to_g ) )

m_to_cm = 100
x_0 = 0.0005
y_width = 0.008
print( "beam_width = {:.4f} [m] = {:.3f} [cm]".format( x_0, x_0 * m_to_cm ) )
print( "y_size = {:.3f} [m] = {:.3f} [cm]".format( y_width, y_width * m_to_cm ) )

I = 0.1
linear_current_density = I / y_width
print( "I = {:.3f} [A]".format( I ) )
print( "linear_current_density = {:.3f} [A/m]".format( linear_current_density ) )

voltage = 1000
q_electron = 1.60218e-19
ev_to_joule = 1.60218e-19
E = voltage * q / q_electron * ev_to_joule
v = sqrt( 2 * E / m )
print( "U = {:.3f} [V]".format( voltage ) )
print( "E = {:.3f} [eV]".format( E / ev_to_joule ) )
print( "v = {:.3e} [m/s]".format( v ) )

eps_0 = 8.85e-12
p = linear_current_density / ( 4 * eps_0 * sqrt( 2 * q / m ) * voltage**1.5 )
x0_2_times_wider = 2 * x_0
z_2_times_wider = sqrt( 2 * x_0 / p )
t_2_times_wider = z_2_times_wider / v
print( "x0_2_times_wider = {:.3f} [m] = {:.3f} [cm]".format(
    x0_2_times_wider, x0_2_times_wider * m_to_cm ) )
print( "t_2_times_wider = {:.3e} [s]".format( t_2_times_wider ) )
print( "z_2_times_wider = {:.3e} [m] = {:.3e} [cm]".format(
    z_2_times_wider, z_2_times_wider * m_to_cm ) )

sim_time = 3.0e-9
n_of_steps = 30
dt = sim_time / n_of_steps
print( "simulation_time = {:.3e} [s]".format( sim_time ) )
print( "number_of_time_steps = {:d}".format( n_of_steps ) )
print( "time_step_size = {:.3e} [s]".format( dt ) )

num_of_real_particles = I * dt / q
print( "num_of_real_particles = {:.3e}".format( num_of_real_particles ) )

num_of_macro_particles = 100
macro_q = I * dt / num_of_macro_particles
macro_m = macro_q / q * m
macro_mean_momentum = macro_m * v
print( "num_of_macro_particles = {:d}".format( num_of_macro_particles ) )
print( "macro_q = {:.3e} [C] = {:.3e} [statC]".format(
    macro_q, macro_q * coulomb_to_statcoulomb ) )
print( "macro_m = {:.3e} [kg] = {:.3e} [g]".format( macro_m, macro_m * kg_to_g ) )
print( "macro_mean_momentum = {:.3e} [kg * m / s] = {:.3e} [g * cm / s]".format(
    macro_mean_momentum, macro_mean_momentum * m_to_cm * kg_to_g ) )
# Out:
# q = 1.600e-19 [C] = 4.797e-10 [statC]
# m = 9.800e-31 [kg] = 9.800e-28 [g]
# beam_width = 0.0005 [m] = 0.050 [cm]
# y_size = 0.008 [m] = 0.800 [cm]
# I = 0.100 [A]
# linear_current_density = 12.500 [A/m]
# U = 1000.000 [V]
# E = 998.639 [eV]
# v = 1.807e+07 [m/s]
# x0_2_times_wider = 0.001 [m] = 0.100 [cm]
# t_2_times_wider = 3.959e-10 [s]
# z_2_times_wider = 7.154e-03 [m] = 7.154e-01 [cm]
# simulation_time = 3.000e-09 [s]
# number_of_time_steps = 30
# time_step_size = 1.000e-10 [s]
# num_of_real_particles = 6.250e+07
# num_of_macro_particles = 100
# macro_q = 1.000e-13 [C] = 2.998e-04 [statC]
# macro_m = 6.125e-25 [kg] = 6.125e-22 [g]
# macro_mean_momentum = 1.107e-17 [kg * m / s] = 1.107e-12 [g * cm / s]

# %% [markdown]
# ## Config values are not exactly the same as estimates

# %%
from ef.config.config import Config
from ef.config.visualizer import Visualizer3d
sim = Config.from_fname('contour_bin.conf')
sim.visualize_all(Visualizer3d())

# %%
# %%sh
# ef contour_bin.conf
# Out:
# Config file is:  contour_bin.conf
# [ TimeGrid ]
# total_time = 3.0e-9
# time_save_step = 3.0e-10
# time_step_size = 1.0e-10
# [ SpatialMesh ]
# grid_x_size = 0.5
# grid_x_step = 0.02
# grid_y_size = 2.0
# grid_y_step = 0.04
# grid_z_size = 8.0
# grid_z_step = 0.2
# [ ParticleSourceBox.cathode_emitter ]
# initial_number_of_particles = 100
# particles_to_generate_each_step = 100
# box_x_left = 0.275
# box_x_right = 0.225
# box_y_bottom = 0.6
# box_y_top = 1.4
# box_z_near = 0.11
# box_z_far = 0.12
# mean_momentum_x = 0
# mean_momentum_y = 0
# mean_momentum_z = 1.107e-12
# temperature = 0.0
# charge = -2.998e-04
# mass = 6.125e-22
# [ BoundaryConditions ]
# boundary_phi_left = 0.0
# boundary_phi_right = 0.0
# boundary_phi_bottom = 0.0
# boundary_phi_top = 0.0
# boundary_phi_near = 0.0
# boundary_phi_far = 0.0
# [ ParticleInteractionModel ]
# particle_interaction_model = PIC
# [ OutputFilename ]
# output_filename_prefix = contour_bin_
# output_filename_suffix = .h5
# Writing initial fields to file
# Writing to file contour_bin_fieldsWithoutParticles_new.h5
# Writing to file contour_bin_fieldsWithoutParticles.h5
# Writing step 0 to file
# Writing to file contour_bin_0000000_new.h5
# Writing to file contour_bin_0000000.h5
# Time step from 0 to 1 of 30
# Time step from 1 to 2 of 30
# Time step from 2 to 3 of 30
# Writing step 3 to file
# Writing to file contour_bin_0000003_new.h5
# Writing to file contour_bin_0000003.h5
# Time step from 3 to 4 of 30
# Time step from 4 to 5 of 30
# Time step from 5 to 6 of 30
# Writing step 6 to file
# Writing to file contour_bin_0000006_new.h5
# Writing to file contour_bin_0000006.h5
# Time step from 6 to 7 of 30
# Time step from 7 to 8 of 30
# Time step from 8 to 9 of 30
# Writing step 9 to file
# Writing to file contour_bin_0000009_new.h5
# Writing to file contour_bin_0000009.h5
# Time step from 9 to 10 of 30
# Time step from 10 to 11 of 30
# Time step from 11 to 12 of 30
# Writing step 12 to file
# Writing to file contour_bin_0000012_new.h5
# Writing to file contour_bin_0000012.h5
# Time step from 12 to 13 of 30
# Time step from 13 to 14 of 30
# Time step from 14 to 15 of 30
# Writing step 15 to file
# Writing to file contour_bin_0000015_new.h5
# Writing to file contour_bin_0000015.h5
# Time step from 15 to 16 of 30
# Time step from 16 to 17 of 30
# Time step from 17 to 18 of 30
# Writing step 18 to file
# Writing to file contour_bin_0000018_new.h5
# Writing to file contour_bin_0000018.h5
# Time step from 18 to 19 of 30
# Time step from 19 to 20 of 30
# Time step from 20 to 21 of 30
# Writing step 21 to file
# Writing to file contour_bin_0000021_new.h5
# Writing to file contour_bin_0000021.h5
# Time step from 21 to 22 of 30
# Time step from 22 to 23 of 30
# Time step from 23 to 24 of 30
# Writing step 24 to file
# Writing to file contour_bin_0000024_new.h5
# Writing to file contour_bin_0000024.h5
# Time step from 24 to 25 of 30
# Time step from 25 to 26 of 30
# Time step from 26 to 27 of 30
# Writing step 27 to file
# Writing to file contour_bin_0000027_new.h5
# Writing to file contour_bin_0000027.h5
# Time step from 27 to 28 of 30
# Time step from 28 to 29 of 30
# Time step from 29 to 30 of 30
# Writing step 30 to file
# Writing to file contour_bin_0000030_new.h5
# Writing to file contour_bin_0000030.h5

# %%
filename = 'contour_bin_0000030_new.h5'
with h5py.File( filename, mode="r") as h5:
    sim = Simulation.init_from_h5(h5, 'contour_', '.h5')

# %%
particles_per_step = sim.particle_sources[0].particles_to_generate_each_step
current = np.abs(
    sim.particle_sources[0].particles_to_generate_each_step *
    sim.particle_sources[0].charge / 
    sim.time_grid.time_step_size
)
current = current / SGSE_conv_unit_current_to_A
print("source current = {} A".format(current))
# Out:
# source current = 0.09993333333333333 A

# %%
mass = sim.particle_sources[0].mass * SI_conv_g_to_kg
charge = sim.particle_sources[0].charge * SI_conv_Fr_to_C
momentum_z = sim.particle_sources[0].mean_momentum[2] * SI_conv_g_to_kg * SI_conv_cm_to_m
print("mass = {} kg".format(mass))
print("charge = {} Coloumb".format(charge))
print("z-momentum = {} kg*m/s".format(momentum_z))
print("charge/mass = {:e} C/kg".format(charge/mass))
# Out:
# mass = 6.125e-25 kg
# charge = -1.00002515740406e-13 Coloumb
# z-momentum = 1.107e-17 kg*m/s
# charge/mass = -1.632694e+11 C/kg

# %%
length_of_cathode = sim.particle_sources[0].shape.size[1] * SI_conv_cm_to_m
half_width = sim.particle_sources[0].shape.size[0] / 2 * SI_conv_cm_to_m
center_of_beam = sim.particle_sources[0].shape.origin[0] * SI_conv_cm_to_m + half_width
print("lenghth of cathode (in y) = {} m".format(length_of_cathode))
print("half width of cathode (in x) = {} m".format(half_width))
print("center of beam (in x) = {} m".format(center_of_beam))
# Out:
# lenghth of cathode (in y) = 0.008 m
# half width of cathode (in x) = 0.0002500000000000001 m
# center of beam (in x) = 0.0025000000000000005 m

# %%
start_z = sim.particle_sources[0].shape.origin[2] * SI_conv_cm_to_m 
end_z = sim.spat_mesh.size[2] * SI_conv_cm_to_m / 4
print("start of beam (in z) = {} m".format(start_z))
print("end of beam (in z) = {} m".format(end_z))
# Out:
# start of beam (in z) = 0.0011 m
# end of beam (in z) = 0.02 m

# %%
energy = (momentum_z * momentum_z) / (2 * mass)
voltage = energy / np.abs(charge)
print("voltage = {} V".format(voltage))
# Out:
# voltage = 1000.3413646203372 V

# %%
current_dens = current / length_of_cathode 
print("current density (along y) = {} A/m".format(current_dens))
# Out:
# current density (along y) = 12.491666666666667 A/m

# %%
eps = 8.85e-12
p_const = 1 / (4*eps*(np.abs(2*charge/mass))**0.5) * current_dens / voltage**1.5 ;   
print("p constant = {}".format(p_const))
# Out:
# p constant = 19.517642975934

# %%
def contour(z_position, half_width, angle, p_const):
    y = half_width + np.tan(angle) * z_position + p_const / 2 * (z_position * z_position)         
    return y

conv_grad_to_rad = np.pi/180
angle = 0 * conv_grad_to_rad          #angle of beam
steps_z = 100000
position_z = np.arange(start_z,end_z,(end_z-start_z)/steps_z) 
# points in z direction, from 0 to 0.01 m with step 0,00001 m 

contour_y = contour(position_z, half_width, angle, p_const)
# countour calculation, m
plt.figure(figsize=(10,10), dpi = (100))
plt.xlabel("Z position, [mm]")
plt.ylabel("X position, [mm]")
plt.plot(sim.particle_arrays[0].positions[..., 2]*SI_conv_cm_to_m*1000,
         ((sim.particle_arrays[0].positions[..., 0]*SI_conv_cm_to_m - center_of_beam)*1000),
             'o',label="calculated_points") #plot particles

plt.plot(position_z*1000, contour_y*1000, color = 'g', lw = 3, label="analytic_curve") # plot countour in cm and move to left z of beam and top x of beam neat cathode
plt.plot(position_z*1000, -1 * contour_y*1000, color = 'g', lw = 3)
plt.legend(bbox_to_anchor=(0.32, 1), loc=1, borderaxespad=0.)
# plt.savefig('countour_beam.png')        # save png picture
# h5.close()                              #close h5 file
